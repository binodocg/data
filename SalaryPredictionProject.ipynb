# %% [markdown]
# <a href="https://colab.research.google.com/github/binodocg/data/blob/main/SalaryPredictionProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Getting Data From Github Repository

# %%
url='https://raw.githubusercontent.com/beenodeshah/data/main/salary.csv'
df=pd.read_csv(url)
df_updated=df.copy()

#irisData=pd.read_csv('https://raw.githubusercontent.com/beenodeshah/data/main/iris.csv')
#irisData

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df_updated
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
le=preprocessing.LabelEncoder()
#columnName=le.fit_transform(columnName)

# %%
df_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
for col in df_updated.columns:
  if(df_updated[col].dtype=='object'):
    #print(col)
    df_updated[col]=le.fit_transform(df[col])

# %%
df_updated.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
df_updated.isnull().sum()
totalNulls=df_updated.isnull().sum().sum()
print(f'\nTotal number of null values : {totalNulls} ')
# Out:
# Total number of null values : 0

# %%
df_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  int64
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  int64
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  int64
#  6   occupation      32561 non-null  int64
#  7   relationship    32561 non-null  int64
#  8   race            32561 non-null  int64
#  9   sex             32561 non-null  int64
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  int64
#  14  salary          32561 non-null  int64
# dtypes: int64(15)
# memory usage: 3.7 MB

# %%
df_updated
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
df.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education-num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_updated.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df,hue='salary')

# %%
plt.bar(df.age,df.salary,color='maroon',width=0.4)
plt.show()

# %%
plt.scatter(df.age,df.salary)
plt.show()

# %%
plt.boxplot(df.age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f831297b610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f831297bb50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f831297b370>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f83129a80d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f83129a8370>],
#  'means': []}

# %%
for col in df.columns:
  if(df[col].dtype!='object'):
    plt.boxplot(df[col])
    print(f'Column Name : {col}')
    plt.show()
# Out:
# Column Name : age
# Column Name : fnlwgt
# Column Name : education-num
# Column Name : capital-gain
# Column Name : capital-loss
# Column Name : hours-per-week

# %% [markdown]
# #Removing Outlier using Standard Deviation Method:
# ![image.png](data:image/png;base64,...)

# %%
age_mean=np.mean(df.age)

# %%
print(age_mean)
# Out:
# 38.58164675532078

# %%
age_sd=np.std(df.age)
print(age_sd)
# Out:
# 13.640223092304275

# %%
limit=age_mean+3*age_sd

# %%
print(limit)
# Out:
# 79.50231603223361

# %%
#print(df[df['age']<limit])
len(df[df['age']>limit])  # This means there are 121 outliers for age column
# Out:
# 121

# %%
len(df)
# Out:
# 32561

# %%
def getOutliers(data):
  for col in data.columns:
    mean=np.mean(data[col])
    sd=np.std(data[col])
    limit=mean+3*sd
    data=data[(data[col]<=limit)]
  return data

# %%
d=getOutliers(df_updated)

# %%
d.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
d
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
sns.boxplot(d.fnlwgt)
# Out:
# <Axes: >

# %%
sns.boxplot(d.age)
# Out:
# <Axes: >

# %%
sns.boxplot(d['hours-per-week'])
# Out:
# <Axes: >

# %%
d.shape
# Out:
# (30108, 15)

# %%
df.shape
# Out:
# (32561, 15)

# %%
len(df)-len(d)
# Out:
# 2453

# %%
2453/32561*100
# Out:
# 7.533552409324037

# %%
d.salary.unique()
# Out:
# array([0, 1])

# %%
# !pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.6/483.6 kB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 25.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 93.3 MB/s eta 0:00:00
# ...

# %%
from pycaret.classification import *
s=setup(data=d,target='salary',session_id=123)
# Out:
# <style type="text/css">
# #T_6ec94_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6ec94" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ec94_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6ec94_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ec94_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ec94_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6ec94_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_6ec94_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ec94_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6ec94_row1_col1" class="data row1 col1" >salary</td>
#     </tr>
#     <tr>
#       <th id="T_6ec94_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best=compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  01:23:55
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
# <style type="text/css">
# #T_97949 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# #####https://towardsdatascience.com/introduction-to-regression-in-python-with-pycaret-d6150b540fc4#:~:text=PyCaret%20is%20an%20open%2Dsource,and%20makes%20you%20more%20productive.

# %%
df.columns

# %%
from sklearn.model_selection import train_test_split

# %%
x=d.drop(columns='salary')
y=d.salary

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print(f'Shape of X_train : {X_train.shape}')
print(f'Shape of test : {X_test.shape}')
print(f'Shape of y_train : {y_train.shape}')
print(f'Shape of y_test : {y_test.shape}')

# %%
from sklearn import linear_model

# %%
lr=linear_model.LogisticRegression()

# %%
logisticModel=lr.fit(X_train,y_train)

# %%
y_pred=logisticModel.predict(X_test)

# %%
y_pred

# %%
y_test

# %%
#accuracy=logisticModel.score(y_test,y_pred)

# %%
#print(f'Accuracy of the logistic regression model : {np.round(accuracy*100,4)}')
from sklearn.metrics import classification_report

# %%
report=classification_report(y_pred,y_test)
print(report)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn import metrics

# %%
cm=metrics.confusion_matrix(y_test,y_pred)

# %%
cm

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['Less or equal to 50k','More than 50k'])
cm_display.plot()
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier(learning_rate=0.1)

# %%
gbmodel=gb.fit(X_train,y_train)

# %%
y_pred=gbmodel.predict(X_test)

# %%
y_pred[0]

# %%
#print(y_pred,'    ',y_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[4454,  231],
#        [ 589,  748]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      4685
#            1       0.76      0.56      0.65      1337
#
#     accuracy                           0.86      6022
#    macro avg       0.82      0.76      0.78      6022
# weighted avg       0.86      0.86      0.86      6022

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['Less or equal to 50k','More than 50k'])
cm_display.plot()
plt.show()

# %% [markdown]
# #####https://towardsdatascience.com/gradient-boosting-classification-explained-through-python-60cc980eeb3d

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dtmodel=dt.fit(X_train,y_train)

# %%
y_pred=dt.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      4685
#            1       0.55      0.60      0.57      1337
#
#     accuracy                           0.80      6022
#    macro avg       0.72      0.73      0.72      6022
# weighted avg       0.81      0.80      0.81      6022

# %%
cm=metrics.confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[4038,  647],
#        [ 539,  798]])

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['Less or equal to 50k','More than 50k'])
cm_display.plot()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()
rfmodel=rf.fit(X_train,y_train)
y_pred=rfmodel.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      4685
#            1       0.71      0.57      0.64      1337
#
#     accuracy                           0.85      6022
#    macro avg       0.80      0.75      0.77      6022
# weighted avg       0.85      0.85      0.85      6022

# %%
cm=metrics.confusion_matrix(y_test,y_pred)
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=['Less or equal to 50k','More than 50k'])
cm_display.plot()
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score,KFold

# %%
models=[]
models.append(('Logistic Regression',LogisticRegression()))
models.append(('Decision Tree',DecisionTreeClassifier()))
models.append(('KNN',KNeighborsClassifier()))
models.append(('Naive Bayes',GaussianNB()))
models.append(('Random Forest',RandomForestClassifier()))
models.append(('XG Boost',GradientBoostingClassifier()))

# %%
models
# Out:
# [('Logistic Regression',
#   LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                      intercept_scaling=1, l1_ratio=None, max_iter=100,
#                      multi_class='auto', n_jobs=None, penalty='l2',
#                      random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                      warm_start=False)),
#  ('Decision Tree',
#   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                          max_depth=None, max_features=None, max_leaf_nodes=None,
#                          min_impurity_decrease=0.0, min_samples_leaf=1,
#                          min_samples_split=2, min_weight_fraction_leaf=0.0,
#                          random_state=None, splitter='best')),
#  ('KNN',
#   KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                        metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                        weights='uniform')),
# ...

# %%
for name,model in models:
  kfold=KFold(n_splits=10,random_state=7,shuffle=True)
  cross_val_sc=cross_val_score(model,x,y,scoring='accuracy',cv=kfold)
  print(f'{name                          }\t{cross_val_sc.mean()}')
# Out:
# Logistic Regression	0.7955357487661521
# Decision Tree	0.8060979950590912
# KNN	0.7877969703556505
# Naive Bayes	0.8026437723915963
# Random Forest	0.8550217530185554
# XG Boost	0.8654175663762219
